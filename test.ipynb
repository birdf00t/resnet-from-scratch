# %%
import matplotlib.pyplot as plt

import conv
import data_func
trainloader, testloader = data_func.get_dataloaders()
images, labels = next(iter(trainloader))
conv = conv.Conv2d(3,16)
output =conv.forward(images)

fig, axes = plt.subplots(4, 4, figsize=(10, 10))
for i, ax in enumerate(axes.flat):
    ax.imshow(output[0, i].detach().numpy(), cmap='viridis')
    ax.set_title(f'channel {i}')
    ax.axis('off')
plt.suptitle('conv output feature maps')
plt.tight_layout()
plt.show()
# Out:
# 훈련 데이터: 50000장
# 테스트 데이터: 10000장
